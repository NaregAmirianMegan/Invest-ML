# %%
#imports
import tensorflow as tf
import numpy as np

# %%
#data
X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]], dtype='float32')
Y = np.array([[0], [1], [1], [0]], dtype='float32')

# %%
#constants
n_h1 = 3
n_h2 = 2
n_output = 1

training_steps = 100000

# %%
#model
x = tf.placeholder(tf.float32, shape=[None, 2])
y = tf.placeholder(tf.float32, shape=None)

# %%
#low level implementation 
with tf.variable_scope("low_level", reuse=tf.AUTO_REUSE):
    h1 = {'weights': tf.Variable(tf.random.normal([2, n_h1])), 
          'biases': tf.Variable(tf.random.normal([n_h1]))}

    h2 = {'weights': tf.Variable(tf.random.normal([n_h1, n_h2])), 
          'biases': tf.Variable(tf.random.normal([n_h2]))}

    output = {'weights': tf.Variable(tf.random.normal([n_h2, n_output])), 
              'biases': tf.Variable(tf.random.normal([n_output]))}

    l1 = tf.add(tf.matmul(X, h1['weights']), h1['biases'])
    l2 = tf.add(tf.matmul(tf.nn.relu(l1), h2['weights']), h2['biases'])
    out_l = tf.add(tf.matmul(tf.nn.relu(l2), output['weights']), output['biases'])

    mse = tf.losses.mean_squared_error(Y, out_l)
    loss = tf.reduce_mean(mse)
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    training_op = optimizer.minimize(loss)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for step in range(training_steps):
            _, curr_loss = sess.run([training_op, loss], feed_dict={x: X, y: Y})
            if step % 1000 == 0:
                print("Predictions:", np.round(sess.run(out_l, feed_dict={x: X}), decimals=0))
                print("Loss:", curr_loss)
# Out:
# Predictions: [[-1.]
#  [-1.]
#  [-2.]
#  [-2.]]
# Loss: 4.941141
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.1723955e-13
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.5527137e-15
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [ 0.]]
# Loss: 3.5527137e-15
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.5527137e-15
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.5527137e-15
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 9.2370556e-14
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.658762e-11
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.0089707e-12
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.5163408e-09
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 6.884626e-10
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 2.0578739e-10
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 4.5059068e-11
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.8013857e-09
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 7.48841e-10
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 5.2600153e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.5183475e-05
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.00043616624
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 6.417942e-10
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.6872726e-11
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.881606e-11
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 7.679635e-11
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.129226e-05
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.859757e-11
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 4.1680526e-10
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.488517e-09
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 9.577221e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 8.2483204e-08
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.2300566e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.4557125e-08
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.2915091e-10
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 2.0607871e-10
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.5741685e-09
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.6372681e-11
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 6.7454806e-08
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.6964501e-09
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.5548285e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.3141585e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.090644e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 9.797925e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.772982e-12
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 5.2349485e-08
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.4052229e-06
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.8890259e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.32823e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.00026561497
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 2.339413e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 4.768701e-10
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.7038403e-07
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 8.4906384e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 1.9189326e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.1495318e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.00013966585
# Predictions: [[ 0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 2.1049829e-13
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.629097e-12
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.9685222e-09
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 2.918199e-11
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 1.2378356e-06
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.0102826e-09
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.3868914e-08
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.00010729808
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 4.417222e-05
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 2.2583002e-09
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.854629e-07
# Predictions: [[-0.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 3.8808386e-07
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 9.355183e-12
# Predictions: [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 3.557954e-11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e3c5d1e63de3> in <module>
#      22         sess.run(tf.global_variables_initializer())
#      23         for step in range(training_steps):
# ---> 24             _, curr_loss = sess.run([training_op, loss], feed_dict={x: X, y: Y})
#      25             if step % 1000 == 0:
#      26                 print("Predictions:", np.round(sess.run(out_l, feed_dict={x: X}), decimals=0))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1131
#    1132           feed_dict_tensor[subfeed_t] = np_val
# -> 1133           feed_map[compat.as_bytes(subfeed_t.name)] = (subfeed_t, subfeed_val)
#    1134
#    1135     # Create a fetch handler to take care of the structure of fetches.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#     352   def name(self):
#     353     """The string name of this tensor."""
# --> 354     if not self._op.name:
#     355       raise ValueError("Operation was not named: %s" % self._op)
#     356     return "%s:%d" % (self._op.name, self._value_index)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in name(self)
#    1897   def name(self):
#    1898     """The full name of this operation."""
# -> 1899     return c_api.TF_OperationName(self._c_op)
#    1900
#    1901   @property
#
# KeyboardInterrupt:

# %%
#mid level implementation
with tf.variable_scope("mid_level", reuse=tf.AUTO_REUSE):
    l1 = tf.layers.dense(x, n_h1, activation=tf.nn.relu)
    l2 = tf.layers.dense(l1, n_h2, activation=tf.nn.relu)
    out_l = tf.layers.dense(l2, n_output)

    mse = tf.losses.mean_squared_error(Y, out_l)
    loss = tf.reduce_mean(mse)
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    training_op = optimizer.minimize(loss)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for step in range(training_steps):
            _, curr_loss = sess.run([training_op, loss], feed_dict={x: X, y: Y})
            if step % 1000 == 0:
                print("Predictions:", np.round(sess.run(out_l, feed_dict={x: X}), decimals=0))
                print("Loss:", curr_loss)
# Out:
# Predictions: [[ 0.]
#  [-0.]
#  [-1.]
#  [-1.]]
# Loss: 1.0884833
# Predictions: [[ 0.]
#  [-0.]
#  [-1.]
#  [-1.]]
# Loss: 1.0051342
# Predictions: [[ 0.]
#  [ 0.]
#  [-1.]
#  [-0.]]
# Loss: 0.9314385
# Predictions: [[ 0.]
#  [ 0.]
#  [-1.]
#  [-0.]]
# Loss: 0.8670878
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.8122938
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.76185036
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.71539706
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.6767987
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.64401186
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.6134123
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.5834106
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.5550767
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [-0.]]
# Loss: 0.52905077
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [ 0.]]
# Loss: 0.5048966
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [ 0.]]
# Loss: 0.48215097
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [ 0.]]
# Loss: 0.46078822
# Predictions: [[ 0.]
#  [ 0.]
#  [-0.]
#  [ 0.]]
# Loss: 0.44076657
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.42206874
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.40465513
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.38848108
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.3735002
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.35673845
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.34126508
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.32740843
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.3218679
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.31643814
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.3111462
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.30599678
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.30100477
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.29615796
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.29145768
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.28690526
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2824895
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.27821508
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.27407056
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.27011988
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2664734
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2629805
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2596346
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2564224
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.25333825
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.25037935
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2475384
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2448108
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.242193
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.23967126
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.23724583
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.23490402
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2311724
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.22764401
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.2243472
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.22112462
# Predictions: [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Loss: 0.21794286
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.21479133
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.21166459
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.20856522
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.20557621
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.20264733
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.19977352
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.19696689
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.1942409
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.1915955
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.1890445
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.18659492
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.18426313
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.18205012
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17997316
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17803414
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17623957
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17459196
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.1731008
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17177674
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.17061806
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16962971
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16880487
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16813761
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16762078
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16724063
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16697924
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16681443
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16672403
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.1666832
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666953
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666682
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666666
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666666
# Predictions: [[ 1.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.16666666
# Predictions: [[ 1.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666666
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666666
# Predictions: [[ 1.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.16666666
# Predictions: [[ 1.]
#  [ 1.]
#  [ 1.]
#  [-0.]]
# Loss: 0.16666667
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666666
# Predictions: [[1.]
#  [1.]
#  [1.]
#  [0.]]
# Loss: 0.16666667
